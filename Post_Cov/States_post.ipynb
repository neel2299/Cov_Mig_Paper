# %%
import pandas as pd
import numpy as np
import json
from datetime import date
import calendar
import networkx as nx
# Out:
# {'ANDAMAN AND NICOBAR IS': 381,
#  'ANDHRA PR': 84581,
#  'ARUNACHAL PR': 1384,
#  'CHAND': 1055,
#  'CHHATTI': 25545,
#  'DADRA AND NAGAR H': 344,
#  'DAMAN AN': 243,
#  'NCT OF ': 16788,
#  'GU': 60440,
#  'HA': 25351,
#  'HIMACHAL PR': 6865,
#  'JAMMU AND KA': 12541,
#  'JHAR': 32988,
#  'KARN': 61095,
#  'K': 33406,
#  'LAKSHA': 64,
#  'MADHYA PR': 72627,
#  'MAHARA': 112374,
#  'MA': 2856,
#  'MEGH': 2967,
#  'MI': 1097,
#  'NAG': 1979,
#  'O': 41974,
#  'PUDUC': 1248,
#  'P': 27743,
#  'RAJA': 68548,
#  'TAMIL': 72147,
#  'TR': 3674,
#  'UTTAR PR': 199812,
#  'UTTARA': 10086,
#  'WEST B': 91276}

# %%
df2=pd.read_excel("INDIA.XLSX")
dic={}
df2
df2=df2.loc[(df2['Unnamed: 5'] == "All ages") & (df2["Unnamed: 4"]=="Total")& (df2["Unnamed: 6"]=="Total")]
df2
for index, row in df2.iterrows():
#     dic[row["Unnamed: 3"].lstrip("State -")[0:-5].upper()]=row["Unnamed: 7"]
    dic[row["Unnamed: 3"].lstrip("State -").upper()]=row["Unnamed: 7"]
#dic
dic["DELHI NCT"]=dic["NCT OF DELHI"]
dic["JAMMU AND KASHMIR"]=dic["JAMMU & KASHMIR"]
dic["SIKKIM"]=dic["IKKIM"]
dic.pop("IKKIM")
dic.pop("JAMMU & KASHMIR")
dic.pop("NCT OF DELHI")
dic
# Out:
# {'INDIA': 141908270,
#  'ANDAMAN AND NICOBAR ISLANDS': 381,
#  'ANDHRA PRADESH': 84581,
#  'ARUNACHAL PRADESH': 1384,
#  'ASSAM': 31206,
#  'BIHAR': 104099,
#  'CHANDIGARH': 1055,
#  'CHHATTISGARH': 25545,
#  'DADRA AND NAGAR HAVELI': 344,
#  'DAMAN AND DIU': 243,
#  'GOA': 1459,
#  'GUJARAT': 60440,
#  'HARYANA': 25351,
#  'HIMACHAL PRADESH': 6865,
#  'JHARKHAND': 32988,
#  'KARNATAKA': 61095,
#  'KERALA': 33406,
#  'LAKSHADWEEP': 64,
#  'MADHYA PRADESH': 72627,
#  'MAHARASHTRA': 112374,
#  'MANIPUR': 2856,
#  'MEGHALAYA': 2967,
#  'MIZORAM': 1097,
#  'NAGALAND': 1979,
#  'ODISHA': 41974,
#  'PUDUCHERRY': 1248,
#  'PUNJAB': 27743,
#  'RAJASTHAN': 68548,
#  'TAMIL NADU': 72147,
#  'TRIPURA': 3674,
#  'UTTAR PRADESH': 199812,
#  'UTTARAKHAND': 10086,
#  'WEST BENGAL': 91276,
#  'DELHI NCT': 16788,
#  'JAMMU AND KASHMIR': 12541,
#  'SIKKIM': 611}

# %%
df=pd.read_csv("Scraped.csv")
x=df["5"][6]
print(x)
df
passengers=[]
for i in range(len(df)):
    temp=0
    x=df["18"][i]
    x=x.replace("EOG","")
    #x=x.strip('][').split(',')
    if(len(x)>8):
        for j in x:
            if (j.startswith("D")):
                temp+=106
            if (j.startswith("H")):
                temp+=22
            if (j.startswith("B")):
                temp+=72
            if (j.startswith("S") or j.startswith("C")):
                temp+=80
            if (j.startswith("A") or j.startswith("E")):
                temp+=54
        if temp==0:
            print(x)
            y=x
        passengers.append(temp)
passengers=list(filter(lambda a: a != 0, passengers))


def df_states(df):
    for i in range(len(df)):
        x=df["19"][i]
        x=x.strip('][').split(',')
        for j in range(1,len(x),2):
            print(x[j])
#df_states(df)

# %%
print(sum(passengers)/len(passengers))
# Out:
# 1592.4638140517698

# %%
#df_states(df)

# %%
#_=x.strip('][').split(',')
dic_month={"Jan":1,"Feb":2,"Mar":3,"Apr":4,"May":5,"Jun":6,"Jul":7,"Aug":8,"Sep":9,"Oct":10,"Nov":11,"Dec":12}

# %%
def create():
    lis=[*dic]
    df=pd.DataFrame(data=0,columns=lis, index = lis)
    return df
dfG=create()
def get_passengers(x):
    temp=0
    x=x.replace("EOG","")
    #x=x.strip('][').split(',')
    if(len(x)>8):
        for j in x:
            if (j.startswith("D")):
                temp+=106
            if (j.startswith("H")):
                temp+=22
            if (j.startswith("B")):
                temp+=72
            if (j.startswith("S") or j.startswith("C")):
                temp+=80
            if (j.startswith("A") or j.startswith("E")):
                temp+=54
    if temp>0:
        return temp
    else:
        return 1590
def get_weekdays(string):
    string=string.replace(" ","")
    #print(len(string), string)
    return len(string)
def separator(string):
    string=string[4:]
    dm,year=string.split(",")
    return dm,year[1:]

def checkruns_weight(row):      #Assumption: The end date is not in 2022. And the start date is either in 2020 or 2021
    s=row[21]
    e=row[22]
    days=0
    try:
        s,years=separator(s)
        e,yeare=separator(e)
        sm,sd=s.split(" ")
        em,ed=e.split(" ")
        sm=dic_month[sm]
        em=dic_month[em]
        date_s=date(int(years),int(sm),int(sd))
        date_e=date(int(yeare),int(em),int(ed))
        days=date_e-date_s
    except:
        try:
            sm,sd=s.split(" ")
            sm=dic_month[sm]
            date_e=date(2021,6,10)
            date_s=date(2021,int(sm),int(sd))
            days=date_e-date_s
        except:
            days=date(2021,6,10)-date(2021,6,10)

    days=days.days
    if days<0:       #365-days for total
        days=360+days
    runs=days/7*get_weekdays(row[14])*get_passengers(row[19])
    return runs
checkruns_weight(df.loc[6])                #
#get_weekdays(df.loc[0][14])
#get_passengers(df.loc[1][19])
# Out:
# 426462.0

# %%
def separator(string):
    string=string[4:]
    dm,year=string.split(",")
    return dm,year[1:]
# Out:
# ('Jul 01', '2021')

# %%
dfG=create()
for index,row in df.iterrows():                 
    x=row[20]
    x=x.strip('][').split(',')
    y=[]
    for i in range(1,len(x),2):
        var=x[i].strip(" '").upper()
        if var not in y:
            y.append(var)
        else:
            pass
    print(y)
    if "TELANGANA" in y:
        if "ANDHRA PRADESH" in y:
            y.remove("TELANGANA")
        else:
            dunno=y.index("TELANGANA")
            y[dunno]="ANDHRA PRADESH"
            
            
    temp=[]
    for i in y:
        try:
            temp.append(dic[i])
        except KeyError:
            if i =="TELANGANA":
                #temp.append(dic("ANDHRA PRADESH"))
                
                if "ANDHRA PRADESH" in y:
                    y.remove(i)
                else:
                    dunno=y.index("TELANGANA")
                    y[dunno]="ANDHRA PRADESH"
                    #print(y)
                    temp.append(dic["ANDHRA PRADESH"])
    print(y)
    print(temp)
    lis=[sum(temp[(i):len(temp)]) for i in range(len(y))]

    capacity=checkruns_weight(row)
    for i in range(len(y)-1):
        for j in range(i+1,len(y)):
            if (i==0):
                den=lis[i]-temp[i]          #Temp is the mig inside of i and and lis is from i to len(y)
                test=y[i]
                test=temp[j]
                dfG[y[i]][y[j]]+=temp[j]*capacity/den
            else:
                den2=lis[i]-temp[i]
                mult1=capacity*temp[i]/lis[i]
                mult2=temp[j]/den2
                dfG[y[i]][y[j]]+=mult1*mult2
            
                
            
#break
# Out:
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# [6010350, 10526724, 11096243, 20620198, 7947991, 14412965]
# ['HARYANA', 'CHANDIGARH', 'DELHI NCT']
# ['HARYANA', 'CHANDIGARH', 'DELHI NCT']
# [3626260, 260786, 2600912]
# ['DELHI NCT', 'HARYANA', 'CHANDIGARH']
# ['DELHI NCT', 'HARYANA', 'CHANDIGARH']
# [2600912, 3626260, 260786]
# ['PUNJAB', 'HARYANA', 'DELHI NCT']
# ['PUNJAB', 'HARYANA', 'DELHI NCT']
# [3743486, 3626260, 2600912]
# ['DELHI NCT', 'HARYANA', 'PUNJAB']
# ['DELHI NCT', 'HARYANA', 'PUNJAB']
# [2600912, 3626260, 3743486]
# ['DELHI NCT', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# ['DELHI NCT', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# [2600912, 3626260, 3743486, 829109]
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'DELHI NCT']
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'DELHI NCT']
# [829109, 3743486, 3626260, 2600912]
# ['RAJASTHAN', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# ['RAJASTHAN', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# [7219526, 14412965, 6909439, 8933321, 2896119]
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'RAJASTHAN']
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'RAJASTHAN']
# [2896119, 8933321, 6909439, 14412965, 7219526]
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'RAJASTHAN']
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'RAJASTHAN']
# [2896119, 8933321, 6909439, 14412965, 7219526]
# ['RAJASTHAN', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# ['RAJASTHAN', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# [7219526, 14412965, 6909439, 8933321, 2896119]
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# [14412965, 7219526, 7947991, 9521542, 20620198]
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR']
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR']
# [2600912, 14412965, 6909439]
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# [2600912, 14412965, 6909439, 2999009, 8933321]
# ['PUNJAB', 'HARYANA', 'UTTAR PRADESH', 'UTTARAKHAND', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# ['PUNJAB', 'HARYANA', 'UTTAR PRADESH', 'UTTARAKHAND', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# [3743486, 3626260, 14412965, 1624197, 6909439, 2999009, 8933321]
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# [6909439, 14412965, 7947991, 20620198, 11096243, 10526724, 6010350]
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# [14412965, 7947991, 20620198, 11096243, 10526724, 6010350]
# ['KARNATAKA']
# ['KARNATAKA']
# [9197706]
# ['KARNATAKA']
# ['KARNATAKA']
# [9197706]
# ['TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL', 'BIHAR', 'ASSAM']
# ['TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL', 'BIHAR', 'ASSAM']
# [10526724, 11096243, 4454572, 8933321, 6909439, 2896119]
# ['BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# ['BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# [6909439, 14412965, 2600912]
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'JHARKHAND', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU']
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'JHARKHAND', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU']
# [2896119, 8933321, 6909439, 2999009, 4454572, 11096243, 10526724]
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# [8933321, 2999009, 6909439, 14412965, 2600912]
# ['TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL', 'JHARKHAND', 'BIHAR', 'ASSAM']
# ['TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL', 'JHARKHAND', 'BIHAR', 'ASSAM']
# [10526724, 11096243, 4454572, 8933321, 2999009, 6909439, 2896119]
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU']
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU']
# [2896119, 8933321, 6909439, 4454572, 11096243, 10526724]
# ['KARNATAKA', 'MAHARASHTRA', 'ANDHRA PRADESH']
# ['KARNATAKA', 'MAHARASHTRA', 'ANDHRA PRADESH']
# [9197706, 20620198, 11096243]
# ['KARNATAKA', 'TELANGANA', 'ANDHRA PRADESH']
# ['KARNATAKA', 'ANDHRA PRADESH']
# [9197706, 11096243]
# ['KARNATAKA', 'ANDHRA PRADESH', 'TELANGANA']
# ['KARNATAKA', 'ANDHRA PRADESH']
# [9197706, 11096243]
# ['MAHARASHTRA', 'KARNATAKA', 'TELANGANA', 'ANDHRA PRADESH']
# ['MAHARASHTRA', 'KARNATAKA', 'ANDHRA PRADESH']
# [20620198, 9197706, 11096243]
# ['KARNATAKA', 'ANDHRA PRADESH', 'MAHARASHTRA']
# ['KARNATAKA', 'ANDHRA PRADESH', 'MAHARASHTRA']
# [9197706, 11096243, 20620198]
# ['KARNATAKA']
# ['KARNATAKA']
# [9197706]
# ['KARNATAKA']
# ['KARNATAKA']
# [9197706]
# ['KARNATAKA', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA']
# ['KARNATAKA', 'ANDHRA PRADESH', 'MAHARASHTRA']
# [9197706, 11096243, 20620198]
# ['KARNATAKA']
# ['KARNATAKA']
# [9197706]
# ['KARNATAKA']
# ['KARNATAKA']
# [9197706]
# ['KARNATAKA']
# ['KARNATAKA']
# [9197706]
# ['KARNATAKA']
# ['KARNATAKA']
# [9197706]
# ['DELHI NCT', 'MADHYA PRADESH', 'UTTAR PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'KARNATAKA']
# ['DELHI NCT', 'MADHYA PRADESH', 'UTTAR PRADESH', 'MAHARASHTRA', 'ANDHRA PRADESH', 'KARNATAKA']
# [2600912, 7947991, 14412965, 20620198, 11096243, 9197706]
# ['KARNATAKA', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# ['KARNATAKA', 'ANDHRA PRADESH', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# [9197706, 11096243, 20620198, 7947991, 14412965, 2600912]
# ['MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# ['MADHYA PRADESH', 'MAHARASHTRA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# [7947991, 20620198, 11096243, 10526724, 6010350]
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# [14412965, 7947991, 20620198]
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# [20620198, 7947991, 14412965]
# ['MAHARASHTRA', 'KARNATAKA', 'ANDHRA PRADESH', 'TAMIL NADU']
# ['MAHARASHTRA', 'KARNATAKA', 'ANDHRA PRADESH', 'TAMIL NADU']
# [20620198, 9197706, 11096243, 10526724]
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# [6909439, 14412965, 7219526, 7947991, 9521542, 20620198]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['HIMACHAL PRADESH', 'HARYANA']
# ['HIMACHAL PRADESH', 'HARYANA']
# [921080, 3626260]
# ['HARYANA', 'HIMACHAL PRADESH']
# ['HARYANA', 'HIMACHAL PRADESH']
# [3626260, 921080]
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# [1624197, 14412965, 2600912]
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# [2600912, 14412965, 1624197]
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'UTTAR PRADESH', 'UTTARAKHAND']
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'UTTAR PRADESH', 'UTTARAKHAND']
# [829109, 3743486, 3626260, 14412965, 1624197]
# ['UTTARAKHAND', 'UTTAR PRADESH', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# ['UTTARAKHAND', 'UTTAR PRADESH', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# [1624197, 14412965, 3626260, 3743486, 829109]
# ['DELHI NCT', 'MADHYA PRADESH', 'UTTAR PRADESH', 'MAHARASHTRA', 'CHHATTISGARH']
# ['DELHI NCT', 'MADHYA PRADESH', 'UTTAR PRADESH', 'MAHARASHTRA', 'CHHATTISGARH']
# [2600912, 7947991, 14412965, 20620198, 3002954]
# ['CHHATTISGARH', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# ['CHHATTISGARH', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# [3002954, 20620198, 7947991, 14412965, 2600912]
# ['JAMMU AND KASHMIR', 'PUNJAB', 'DELHI NCT']
# ['JAMMU AND KASHMIR', 'PUNJAB', 'DELHI NCT']
# [829109, 3743486, 2600912]
# ['DELHI NCT', 'PUNJAB', 'JAMMU AND KASHMIR']
# ['DELHI NCT', 'PUNJAB', 'JAMMU AND KASHMIR']
# [2600912, 3743486, 829109]
# ['CHANDIGARH', 'HARYANA', 'DELHI NCT']
# ['CHANDIGARH', 'HARYANA', 'DELHI NCT']
# [260786, 3626260, 2600912]
# ['DELHI NCT', 'HARYANA', 'CHANDIGARH']
# ['DELHI NCT', 'HARYANA', 'CHANDIGARH']
# [2600912, 3626260, 260786]
# ['PUNJAB']
# ['PUNJAB']
# [3743486]
# ['PUNJAB']
# ['PUNJAB']
# [3743486]
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# [2600912, 14412965, 1624197]
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# [1624197, 14412965, 2600912]
# ['HARYANA', 'CHANDIGARH', 'DELHI NCT']
# ['HARYANA', 'CHANDIGARH', 'DELHI NCT']
# [3626260, 260786, 2600912]
# ['DELHI NCT', 'HARYANA', 'CHANDIGARH']
# ['DELHI NCT', 'HARYANA', 'CHANDIGARH']
# [2600912, 3626260, 260786]
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# [7219526, 3626260, 2600912]
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN']
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN']
# [2600912, 3626260, 7219526]
# ['PUNJAB', 'HARYANA', 'DELHI NCT']
# ['PUNJAB', 'HARYANA', 'DELHI NCT']
# [3743486, 3626260, 2600912]
# ['DELHI NCT', 'HARYANA', 'PUNJAB']
# ['DELHI NCT', 'HARYANA', 'PUNJAB']
# [2600912, 3626260, 3743486]
# ['HIMACHAL PRADESH', 'HARYANA']
# ['HIMACHAL PRADESH', 'HARYANA']
# [921080, 3626260]
# ['HARYANA', 'HIMACHAL PRADESH']
# ['HARYANA', 'HIMACHAL PRADESH']
# [3626260, 921080]
# ['HIMACHAL PRADESH', 'HARYANA']
# ['HIMACHAL PRADESH', 'HARYANA']
# [921080, 3626260]
# ['HARYANA', 'HIMACHAL PRADESH']
# ['HARYANA', 'HIMACHAL PRADESH']
# [3626260, 921080]
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# [1624197, 14412965, 2600912]
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# [2600912, 14412965, 1624197]
# ['JHARKHAND', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA', 'PUNJAB']
# ['JHARKHAND', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA', 'PUNJAB']
# [2999009, 8933321, 6909439, 14412965, 1624197, 3626260, 3743486]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# [20620198, 9521542, 7947991, 7219526, 14412965]
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# [20620198, 7947991, 14412965]
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# [14412965, 7947991, 20620198]
# ['KARNATAKA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# ['KARNATAKA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# [9197706, 11096243, 10526724, 6010350]
# ['TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA', 'MAHARASHTRA']
# ['TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA', 'MAHARASHTRA']
# [10526724, 11096243, 9197706, 20620198]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# [20620198, 9521542, 7947991, 7219526, 14412965]
# ['MAHARASHTRA', 'GUJARAT', 'RAJASTHAN']
# ['MAHARASHTRA', 'GUJARAT', 'RAJASTHAN']
# [20620198, 9521542, 7219526]
# ['RAJASTHAN', 'GUJARAT', 'MAHARASHTRA']
# ['RAJASTHAN', 'GUJARAT', 'MAHARASHTRA']
# [7219526, 9521542, 20620198]
# ['DELHI NCT', 'UTTAR PRADESH']
# ['DELHI NCT', 'UTTAR PRADESH']
# [2600912, 14412965]
# ['UTTAR PRADESH', 'DELHI NCT']
# ['UTTAR PRADESH', 'DELHI NCT']
# [14412965, 2600912]
# ['UTTAR PRADESH', 'BIHAR']
# ['UTTAR PRADESH', 'BIHAR']
# [14412965, 6909439]
# ['BIHAR', 'UTTAR PRADESH']
# ['BIHAR', 'UTTAR PRADESH']
# [6909439, 14412965]
# ['UTTAR PRADESH', 'BIHAR']
# ['UTTAR PRADESH', 'BIHAR']
# [14412965, 6909439]
# ['BIHAR', 'UTTAR PRADESH']
# ['BIHAR', 'UTTAR PRADESH']
# [6909439, 14412965]
# ['UTTAR PRADESH', 'BIHAR']
# ['UTTAR PRADESH', 'BIHAR']
# [14412965, 6909439]
# ['BIHAR', 'UTTAR PRADESH']
# ['BIHAR', 'UTTAR PRADESH']
# [6909439, 14412965]
# ['UTTAR PRADESH', 'BIHAR']
# ['UTTAR PRADESH', 'BIHAR']
# [14412965, 6909439]
# ['BIHAR', 'UTTAR PRADESH']
# ['BIHAR', 'UTTAR PRADESH']
# [6909439, 14412965]
# ['MAHARASHTRA', 'GOA', 'KARNATAKA']
# ['MAHARASHTRA', 'GOA', 'KARNATAKA']
# [20620198, 435131, 9197706]
# ['KARNATAKA', 'GOA', 'MAHARASHTRA']
# ['KARNATAKA', 'GOA', 'MAHARASHTRA']
# [9197706, 435131, 20620198]
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'KARNATAKA', 'TAMIL NADU']
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'ANDHRA PRADESH', 'KARNATAKA', 'TAMIL NADU']
# [2600912, 14412965, 7947991, 20620198, 11096243, 9197706, 10526724]
# ['TAMIL NADU', 'KARNATAKA', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# ['TAMIL NADU', 'KARNATAKA', 'ANDHRA PRADESH', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# [10526724, 9197706, 11096243, 20620198, 7947991, 14412965, 2600912]
# ['MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA', 'TAMIL NADU']
# ['MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA', 'TAMIL NADU']
# [20620198, 435131, 9197706, 6010350, 10526724]
# ['TAMIL NADU', 'KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA']
# ['TAMIL NADU', 'KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA']
# [10526724, 6010350, 9197706, 435131, 20620198]
# ['CHHATTISGARH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# ['CHHATTISGARH', 'MAHARASHTRA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# [3002954, 20620198, 11096243, 10526724, 6010350]
# ['TAMIL NADU', 'KERALA', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'CHHATTISGARH']
# ['TAMIL NADU', 'KERALA', 'ANDHRA PRADESH', 'MAHARASHTRA', 'CHHATTISGARH']
# [10526724, 6010350, 11096243, 20620198, 3002954]
# ['GUJARAT', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU']
# ['GUJARAT', 'MAHARASHTRA', 'ANDHRA PRADESH', 'TAMIL NADU']
# [9521542, 20620198, 11096243, 10526724]
# ['RAJASTHAN', 'GUJARAT', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU']
# ['RAJASTHAN', 'GUJARAT', 'MAHARASHTRA', 'ANDHRA PRADESH', 'TAMIL NADU']
# [7219526, 9521542, 20620198, 11096243, 10526724]
# ['TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'GUJARAT']
# ['TAMIL NADU', 'ANDHRA PRADESH', 'MAHARASHTRA', 'GUJARAT']
# [10526724, 11096243, 20620198, 9521542]
# ['TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'GUJARAT', 'RAJASTHAN']
# ['TAMIL NADU', 'ANDHRA PRADESH', 'MAHARASHTRA', 'GUJARAT', 'RAJASTHAN']
# [10526724, 11096243, 20620198, 9521542, 7219526]
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH']
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'MAHARASHTRA', 'MADHYA PRADESH']
# [6010350, 10526724, 11096243, 20620198, 7947991]
# ['RAJASTHAN', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU']
# ['RAJASTHAN', 'MADHYA PRADESH', 'MAHARASHTRA', 'ANDHRA PRADESH', 'TAMIL NADU']
# [7219526, 7947991, 20620198, 11096243, 10526724]
# ['TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'RAJASTHAN']
# ['TAMIL NADU', 'ANDHRA PRADESH', 'MAHARASHTRA', 'MADHYA PRADESH', 'RAJASTHAN']
# [10526724, 11096243, 20620198, 7947991, 7219526]
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU']
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'ANDHRA PRADESH', 'TAMIL NADU']
# [14412965, 7947991, 20620198, 11096243, 10526724]
# ['TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# ['TAMIL NADU', 'ANDHRA PRADESH', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# [10526724, 11096243, 20620198, 7947991, 14412965]
# ['GUJARAT', 'MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA']
# ['GUJARAT', 'MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA']
# [9521542, 20620198, 435131, 9197706, 6010350]
# ['KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA', 'GUJARAT']
# ['KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA', 'GUJARAT']
# [6010350, 9197706, 435131, 20620198, 9521542]
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA']
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA']
# [6010350, 10526724, 11096243, 9197706]
# ['DELHI NCT', 'UTTAR PRADESH']
# ['DELHI NCT', 'UTTAR PRADESH']
# [2600912, 14412965]
# ['UTTAR PRADESH', 'DELHI NCT']
# ['UTTAR PRADESH', 'DELHI NCT']
# [14412965, 2600912]
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# [14412965, 7219526, 7947991, 9521542, 20620198]
# ['MAHARASHTRA', 'GUJARAT']
# ['MAHARASHTRA', 'GUJARAT']
# [20620198, 9521542]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['MAHARASHTRA']
# ['MAHARASHTRA']
# [20620198]
# ['KARNATAKA', 'TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'JHARKHAND']
# ['KARNATAKA', 'TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'JHARKHAND']
# [9197706, 10526724, 11096243, 4454572, 2999009]
# ['JHARKHAND', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KARNATAKA']
# ['JHARKHAND', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KARNATAKA']
# [2999009, 4454572, 11096243, 10526724, 9197706]
# ['MAHARASHTRA']
# ['MAHARASHTRA']
# [20620198]
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'RAJASTHAN', 'GUJARAT']
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'RAJASTHAN', 'GUJARAT']
# [829109, 3743486, 3626260, 7219526, 9521542]
# ['GUJARAT', 'RAJASTHAN', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# ['GUJARAT', 'RAJASTHAN', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# [9521542, 7219526, 3626260, 3743486, 829109]
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN', 'GUJARAT']
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN', 'GUJARAT']
# [2600912, 3626260, 7219526, 9521542]
# ['GUJARAT', 'RAJASTHAN', 'HARYANA', 'DELHI NCT']
# ['GUJARAT', 'RAJASTHAN', 'HARYANA', 'DELHI NCT']
# [9521542, 7219526, 3626260, 2600912]
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH']
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH']
# [2600912, 14412965, 7947991]
# ['CHHATTISGARH', 'MAHARASHTRA', 'GUJARAT']
# ['CHHATTISGARH', 'MAHARASHTRA', 'GUJARAT']
# [3002954, 20620198, 9521542]
# ['GUJARAT', 'MAHARASHTRA', 'CHHATTISGARH']
# ['GUJARAT', 'MAHARASHTRA', 'CHHATTISGARH']
# [9521542, 20620198, 3002954]
# ['RAJASTHAN', 'GUJARAT', 'MAHARASHTRA']
# ['RAJASTHAN', 'GUJARAT', 'MAHARASHTRA']
# [7219526, 9521542, 20620198]
# ['MAHARASHTRA', 'GUJARAT', 'RAJASTHAN']
# ['MAHARASHTRA', 'GUJARAT', 'RAJASTHAN']
# [20620198, 9521542, 7219526]
# ['RAJASTHAN', 'GUJARAT', 'MAHARASHTRA']
# ['RAJASTHAN', 'GUJARAT', 'MAHARASHTRA']
# [7219526, 9521542, 20620198]
# ['MAHARASHTRA', 'GUJARAT', 'RAJASTHAN']
# ['MAHARASHTRA', 'GUJARAT', 'RAJASTHAN']
# [20620198, 9521542, 7219526]
# ['MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# ['MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# [7947991, 14412965, 2600912]
# ['RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# ['RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# [7219526, 7947991, 9521542, 20620198]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN']
# [20620198, 9521542, 7947991, 7219526]
# ['GUJARAT', 'MAHARASHTRA']
# ['GUJARAT', 'MAHARASHTRA']
# [9521542, 20620198]
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# [2896119, 8933321, 6909439, 4454572, 11096243, 10526724, 6010350]
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL', 'BIHAR', 'ASSAM']
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL', 'BIHAR', 'ASSAM']
# [6010350, 10526724, 11096243, 4454572, 8933321, 6909439, 2896119]
# ['WEST BENGAL', 'ODISHA', 'ANDHRA PRADESH', 'TELANGANA']
# ['WEST BENGAL', 'ODISHA', 'ANDHRA PRADESH']
# [8933321, 4454572, 11096243]
# ['MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND']
# ['MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND']
# [20620198, 3002954, 4454572, 2999009]
# ['HARYANA', 'PUNJAB', 'RAJASTHAN']
# ['HARYANA', 'PUNJAB', 'RAJASTHAN']
# [3626260, 3743486, 7219526]
# ['RAJASTHAN', 'PUNJAB', 'HARYANA']
# ['RAJASTHAN', 'PUNJAB', 'HARYANA']
# [7219526, 3743486, 3626260]
# ['MADHYA PRADESH', 'RAJASTHAN']
# ['MADHYA PRADESH', 'RAJASTHAN']
# [7947991, 7219526]
# ['RAJASTHAN', 'MADHYA PRADESH']
# ['RAJASTHAN', 'MADHYA PRADESH']
# [7219526, 7947991]
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN']
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN']
# [2600912, 3626260, 7219526]
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# [7219526, 3626260, 2600912]
# ['PUNJAB', 'HARYANA', 'RAJASTHAN']
# ['PUNJAB', 'HARYANA', 'RAJASTHAN']
# [3743486, 3626260, 7219526]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['RAJASTHAN', 'PUNJAB', 'HARYANA']
# ['RAJASTHAN', 'PUNJAB', 'HARYANA']
# [7219526, 3743486, 3626260]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['PUNJAB', 'HARYANA', 'RAJASTHAN']
# ['PUNJAB', 'HARYANA', 'RAJASTHAN']
# [3743486, 3626260, 7219526]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['RAJASTHAN', 'HARYANA', 'PUNJAB']
# ['RAJASTHAN', 'HARYANA', 'PUNJAB']
# [7219526, 3626260, 3743486]
# ['RAJASTHAN', 'MADHYA PRADESH']
# ['RAJASTHAN', 'MADHYA PRADESH']
# [7219526, 7947991]
# ['PUNJAB', 'HARYANA', 'RAJASTHAN']
# ['PUNJAB', 'HARYANA', 'RAJASTHAN']
# [3743486, 3626260, 7219526]
# ['MADHYA PRADESH', 'RAJASTHAN']
# ['MADHYA PRADESH', 'RAJASTHAN']
# [7947991, 7219526]
# ['RAJASTHAN', 'PUNJAB', 'HARYANA']
# ['RAJASTHAN', 'PUNJAB', 'HARYANA']
# [7219526, 3743486, 3626260]
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN']
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN']
# [2600912, 3626260, 7219526]
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# [7219526, 3626260, 2600912]
# ['UTTAR PRADESH', 'RAJASTHAN', 'HARYANA']
# ['UTTAR PRADESH', 'RAJASTHAN', 'HARYANA']
# [14412965, 7219526, 3626260]
# ['HARYANA', 'RAJASTHAN', 'UTTAR PRADESH']
# ['HARYANA', 'RAJASTHAN', 'UTTAR PRADESH']
# [3626260, 7219526, 14412965]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN']
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN']
# [2600912, 3626260, 7219526]
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# [7219526, 3626260, 2600912]
# ['RAJASTHAN', 'MADHYA PRADESH']
# ['RAJASTHAN', 'MADHYA PRADESH']
# [7219526, 7947991]
# ['MADHYA PRADESH', 'RAJASTHAN']
# ['MADHYA PRADESH', 'RAJASTHAN']
# [7947991, 7219526]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# [20620198, 9521542, 7947991, 7219526, 14412965, 6909439]
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT']
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT']
# [6909439, 14412965, 7219526, 7947991, 9521542]
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# [6909439, 14412965, 7219526, 7947991, 9521542, 20620198]
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT']
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT']
# [6909439, 14412965, 7219526, 7947991, 9521542]
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR']
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR']
# [2600912, 14412965, 6909439]
# ['BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# ['BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# [6909439, 14412965, 2600912]
# ['MADHYA PRADESH', 'MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA', 'TAMIL NADU']
# ['MADHYA PRADESH', 'MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA', 'TAMIL NADU']
# [7947991, 20620198, 435131, 9197706, 6010350, 10526724]
# ['MADHYA PRADESH', 'MAHARASHTRA']
# ['MADHYA PRADESH', 'MAHARASHTRA']
# [7947991, 20620198]
# ['MAHARASHTRA', 'MADHYA PRADESH']
# ['MAHARASHTRA', 'MADHYA PRADESH']
# [20620198, 7947991]
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# [20620198, 7947991, 14412965]
# ['WEST BENGAL', 'JHARKHAND', 'ODISHA', 'CHHATTISGARH', 'MAHARASHTRA']
# ['WEST BENGAL', 'JHARKHAND', 'ODISHA', 'CHHATTISGARH', 'MAHARASHTRA']
# [8933321, 2999009, 4454572, 3002954, 20620198]
# ['MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND', 'WEST BENGAL']
# ['MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND', 'WEST BENGAL']
# [20620198, 3002954, 4454572, 2999009, 8933321]
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# [8933321, 2999009, 6909439, 14412965, 2600912]
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# [20620198, 7947991, 14412965]
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# ['UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# [14412965, 7947991, 20620198]
# ['JHARKHAND', 'WEST BENGAL', 'BIHAR', 'ASSAM']
# ['JHARKHAND', 'WEST BENGAL', 'BIHAR', 'ASSAM']
# [2999009, 8933321, 6909439, 2896119]
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR', 'JHARKHAND']
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR', 'JHARKHAND']
# [2600912, 14412965, 6909439, 2999009]
# ['DELHI NCT', 'UTTAR PRADESH', 'JHARKHAND']
# ['DELHI NCT', 'UTTAR PRADESH', 'JHARKHAND']
# [2600912, 14412965, 2999009]
# ['JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# ['JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# [2999009, 6909439, 14412965, 2600912]
# ['CHANDIGARH', 'HARYANA', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM', 'NAGALAND']
# ['CHANDIGARH', 'HARYANA', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM', 'NAGALAND']
# [260786, 3626260, 14412965, 6909439, 8933321, 2896119, 254685]
# ['JHARKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# ['JHARKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# [2999009, 14412965, 2600912]
# ['ASSAM', 'NAGALAND', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'HARYANA', 'CHANDIGARH']
# ['ASSAM', 'NAGALAND', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'HARYANA', 'CHANDIGARH']
# [2896119, 254685, 8933321, 6909439, 14412965, 3626260, 260786]
# ['BIHAR']
# ['BIHAR']
# [6909439]
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'JHARKHAND']
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'JHARKHAND']
# [2896119, 8933321, 6909439, 2999009]
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# [8933321, 2999009, 6909439, 14412965, 2600912]
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# [2600912, 14412965, 6909439, 2999009, 8933321]
# ['ODISHA', 'WEST BENGAL', 'BIHAR', 'ASSAM']
# ['ODISHA', 'WEST BENGAL', 'BIHAR', 'ASSAM']
# [4454572, 8933321, 6909439, 2896119]
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# [2600912, 14412965, 6909439, 2999009, 8933321]
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR']
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR']
# [2600912, 14412965, 6909439]
# ['MAHARASHTRA', 'GOA']
# ['MAHARASHTRA', 'GOA']
# [20620198, 435131]
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'ODISHA', 'ANDHRA PRADESH', 'TELANGANA']
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'ODISHA', 'ANDHRA PRADESH']
# [2896119, 8933321, 6909439, 4454572, 11096243]
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT']
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT']
# [2896119, 8933321, 6909439, 14412965, 7219526, 7947991, 9521542]
# ['GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# ['GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# [9521542, 7947991, 7219526, 14412965, 6909439, 8933321, 2896119]
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# [2896119, 8933321, 6909439, 14412965, 1624197, 3626260, 3743486, 829109]
# ['HARYANA', 'RAJASTHAN', 'GUJARAT', 'MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA', 'TAMIL NADU']
# ['HARYANA', 'RAJASTHAN', 'GUJARAT', 'MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA', 'TAMIL NADU']
# [3626260, 7219526, 9521542, 20620198, 435131, 9197706, 6010350, 10526724]
# ['WEST BENGAL', 'BIHAR']
# ['WEST BENGAL', 'BIHAR']
# [8933321, 6909439]
# ['WEST BENGAL', 'JHARKHAND']
# ['WEST BENGAL', 'JHARKHAND']
# [8933321, 2999009]
# ['WEST BENGAL', 'JHARKHAND']
# ['WEST BENGAL', 'JHARKHAND']
# [8933321, 2999009]
# ['WEST BENGAL', 'BIHAR', 'JHARKHAND']
# ['WEST BENGAL', 'BIHAR', 'JHARKHAND']
# [8933321, 6909439, 2999009]
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR']
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR']
# [8933321, 2999009, 6909439]
# ['BIHAR', 'WEST BENGAL']
# ['BIHAR', 'WEST BENGAL']
# [6909439, 8933321]
# ['WEST BENGAL', 'BIHAR']
# ['WEST BENGAL', 'BIHAR']
# [8933321, 6909439]
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'RAJASTHAN', 'HARYANA', 'DELHI NCT', 'PUNJAB']
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'RAJASTHAN', 'HARYANA', 'DELHI NCT', 'PUNJAB']
# [20620198, 7947991, 14412965, 7219526, 3626260, 2600912, 3743486]
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'JHARKHAND']
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'JHARKHAND']
# [2896119, 8933321, 6909439, 2999009]
# ['BIHAR', 'JHARKHAND', 'WEST BENGAL', 'ASSAM']
# ['BIHAR', 'JHARKHAND', 'WEST BENGAL', 'ASSAM']
# [6909439, 2999009, 8933321, 2896119]
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# [6909439, 14412965, 7219526, 7947991, 9521542, 20620198]
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# [7219526, 3626260, 2600912, 14412965, 6909439, 8933321, 2896119]
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT', 'HARYANA', 'RAJASTHAN']
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT', 'HARYANA', 'RAJASTHAN']
# [2896119, 8933321, 6909439, 14412965, 2600912, 3626260, 7219526]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['MAHARASHTRA', 'GOA']
# ['MAHARASHTRA', 'GOA']
# [20620198, 435131]
# ['GOA', 'MAHARASHTRA']
# ['GOA', 'MAHARASHTRA']
# [435131, 20620198]
# ['GOA', 'MAHARASHTRA']
# ['GOA', 'MAHARASHTRA']
# [435131, 20620198]
# ['GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# ['GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# [9521542, 7947991, 7219526, 14412965, 6909439, 8933321, 2896119]
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT']
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT']
# [2896119, 8933321, 6909439, 14412965, 7219526, 7947991, 9521542]
# ['TELANGANA', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL']
# ['ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL']
# [11096243, 4454572, 8933321]
# ['WEST BENGAL', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KARNATAKA']
# ['WEST BENGAL', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KARNATAKA']
# [8933321, 4454572, 11096243, 10526724, 9197706]
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# [2600912, 14412965, 6909439, 8933321, 2896119]
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# ['ASSAM', 'WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# [2896119, 8933321, 6909439, 14412965, 2600912]
# ['MAHARASHTRA', 'CHHATTISGARH', 'JHARKHAND', 'WEST BENGAL']
# ['MAHARASHTRA', 'CHHATTISGARH', 'JHARKHAND', 'WEST BENGAL']
# [20620198, 3002954, 2999009, 8933321]
# ['WEST BENGAL', 'ASSAM']
# ['WEST BENGAL', 'ASSAM']
# [8933321, 2896119]
# ['ASSAM', 'WEST BENGAL']
# ['ASSAM', 'WEST BENGAL']
# [2896119, 8933321]
# ['WEST BENGAL', 'BIHAR']
# ['WEST BENGAL', 'BIHAR']
# [8933321, 6909439]
# ['WEST BENGAL', 'BIHAR']
# ['WEST BENGAL', 'BIHAR']
# [8933321, 6909439]
# ['WEST BENGAL', 'BIHAR']
# ['WEST BENGAL', 'BIHAR']
# [8933321, 6909439]
# ['WEST BENGAL', 'BIHAR']
# ['WEST BENGAL', 'BIHAR']
# [8933321, 6909439]
# ['WEST BENGAL']
# ['WEST BENGAL']
# [8933321]
# ['WEST BENGAL']
# ['WEST BENGAL']
# [8933321]
# ['WEST BENGAL']
# ['WEST BENGAL']
# [8933321]
# ['WEST BENGAL']
# ['WEST BENGAL']
# [8933321]
# ['BIHAR', 'WEST BENGAL']
# ['BIHAR', 'WEST BENGAL']
# [6909439, 8933321]
# ['WEST BENGAL', 'BIHAR']
# ['WEST BENGAL', 'BIHAR']
# [8933321, 6909439]
# ['BIHAR', 'WEST BENGAL']
# ['BIHAR', 'WEST BENGAL']
# [6909439, 8933321]
# ['WEST BENGAL', 'BIHAR']
# ['WEST BENGAL', 'BIHAR']
# [8933321, 6909439]
# ['BIHAR']
# ['BIHAR']
# [6909439]
# ['BIHAR']
# ['BIHAR']
# [6909439]
# ['BIHAR']
# ['BIHAR']
# [6909439]
# ['BIHAR']
# ['BIHAR']
# [6909439]
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT']
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT']
# [6909439, 14412965, 7219526, 7947991, 9521542]
# ['GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# ['GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# [9521542, 7947991, 7219526, 14412965, 6909439]
# ['GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# ['GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# [9521542, 7947991, 7219526, 14412965, 6909439]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# [20620198, 9521542, 7947991, 7219526, 14412965, 6909439]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# [20620198, 9521542, 7947991, 7219526, 14412965, 6909439]
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# [6909439, 14412965, 7219526, 7947991, 9521542, 20620198]
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT']
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT']
# [14412965, 7219526, 7947991, 9521542]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# [20620198, 9521542, 7947991, 7219526, 14412965, 6909439]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# [20620198, 9521542, 7947991, 7219526, 14412965]
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# [6909439, 14412965, 7219526, 7947991, 9521542, 20620198]
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# [14412965, 7219526, 7947991, 9521542, 20620198]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# [20620198, 9521542, 7947991, 7219526, 14412965, 6909439]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# [20620198, 9521542, 7947991, 7219526, 14412965]
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'GUJARAT']
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'GUJARAT']
# [6909439, 14412965, 7947991, 20620198, 9521542]
# ['GUJARAT', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR']
# ['GUJARAT', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR']
# [9521542, 20620198, 7947991, 14412965, 6909439]
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# [14412965, 7219526, 7947991, 9521542, 20620198]
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'GUJARAT']
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'GUJARAT']
# [6909439, 14412965, 7947991, 20620198, 9521542]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# [20620198, 9521542, 7947991, 7219526, 14412965]
# ['GUJARAT', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR']
# ['GUJARAT', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR']
# [9521542, 20620198, 7947991, 14412965, 6909439]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# [20620198, 9521542, 7947991, 7219526, 14412965, 6909439]
# ['TAMIL NADU', 'KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA', 'MADHYA PRADESH']
# ['TAMIL NADU', 'KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA', 'MADHYA PRADESH']
# [10526724, 6010350, 9197706, 435131, 20620198, 7947991]
# ['WEST BENGAL', 'JHARKHAND', 'CHHATTISGARH', 'MAHARASHTRA']
# ['WEST BENGAL', 'JHARKHAND', 'CHHATTISGARH', 'MAHARASHTRA']
# [8933321, 2999009, 3002954, 20620198]
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# [2600912, 14412965, 1624197]
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# [1624197, 14412965, 2600912]
# ['ODISHA', 'CHHATTISGARH', 'MADHYA PRADESH', 'RAJASTHAN']
# ['ODISHA', 'CHHATTISGARH', 'MADHYA PRADESH', 'RAJASTHAN']
# [4454572, 3002954, 7947991, 7219526]
# ['RAJASTHAN', 'MADHYA PRADESH', 'CHHATTISGARH', 'ODISHA']
# ['RAJASTHAN', 'MADHYA PRADESH', 'CHHATTISGARH', 'ODISHA']
# [7219526, 7947991, 3002954, 4454572]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['WEST BENGAL', 'ODISHA', 'ANDHRA PRADESH', 'TELANGANA']
# ['WEST BENGAL', 'ODISHA', 'ANDHRA PRADESH']
# [8933321, 4454572, 11096243]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['RAJASTHAN', 'HARYANA']
# ['RAJASTHAN', 'HARYANA']
# [7219526, 3626260]
# ['HARYANA', 'RAJASTHAN']
# ['HARYANA', 'RAJASTHAN']
# [3626260, 7219526]
# ['HARYANA', 'RAJASTHAN']
# ['HARYANA', 'RAJASTHAN']
# [3626260, 7219526]
# ['RAJASTHAN', 'HARYANA']
# ['RAJASTHAN', 'HARYANA']
# [7219526, 3626260]
# ['UTTAR PRADESH', 'MADHYA PRADESH']
# ['UTTAR PRADESH', 'MADHYA PRADESH']
# [14412965, 7947991]
# ['MADHYA PRADESH', 'UTTAR PRADESH']
# ['MADHYA PRADESH', 'UTTAR PRADESH']
# [7947991, 14412965]
# ['MADHYA PRADESH']
# ['MADHYA PRADESH']
# [7947991]
# ['MADHYA PRADESH']
# ['MADHYA PRADESH']
# [7947991]
# ['DELHI NCT', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# ['DELHI NCT', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# [2600912, 3626260, 3743486, 829109]
# ['DELHI NCT', 'HARYANA', 'UTTAR PRADESH']
# ['DELHI NCT', 'HARYANA', 'UTTAR PRADESH']
# [2600912, 3626260, 14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['DELHI NCT', 'HARYANA', 'PUNJAB', 'RAJASTHAN']
# ['DELHI NCT', 'HARYANA', 'PUNJAB', 'RAJASTHAN']
# [2600912, 3626260, 3743486, 7219526]
# ['RAJASTHAN', 'PUNJAB', 'HARYANA', 'DELHI NCT']
# ['RAJASTHAN', 'PUNJAB', 'HARYANA', 'DELHI NCT']
# [7219526, 3743486, 3626260, 2600912]
# ['DELHI NCT', 'HARYANA', 'PUNJAB', 'HIMACHAL PRADESH']
# ['DELHI NCT', 'HARYANA', 'PUNJAB', 'HIMACHAL PRADESH']
# [2600912, 3626260, 3743486, 921080]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH', 'HARYANA', 'DELHI NCT']
# ['UTTAR PRADESH', 'HARYANA', 'DELHI NCT']
# [14412965, 3626260, 2600912]
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN']
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN']
# [2600912, 3626260, 7219526]
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'DELHI NCT']
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'DELHI NCT']
# [829109, 3743486, 3626260, 2600912]
# ['PUNJAB', 'HARYANA', 'DELHI NCT']
# ['PUNJAB', 'HARYANA', 'DELHI NCT']
# [3743486, 3626260, 2600912]
# ['DELHI NCT', 'HARYANA', 'PUNJAB']
# ['DELHI NCT', 'HARYANA', 'PUNJAB']
# [2600912, 3626260, 3743486]
# ['HARYANA', 'PUNJAB', 'RAJASTHAN']
# ['HARYANA', 'PUNJAB', 'RAJASTHAN']
# [3626260, 3743486, 7219526]
# ['RAJASTHAN', 'PUNJAB', 'HARYANA']
# ['RAJASTHAN', 'PUNJAB', 'HARYANA']
# [7219526, 3743486, 3626260]
# ['HIMACHAL PRADESH', 'PUNJAB', 'HARYANA', 'DELHI NCT']
# ['HIMACHAL PRADESH', 'PUNJAB', 'HARYANA', 'DELHI NCT']
# [921080, 3743486, 3626260, 2600912]
# ['JAMMU AND KASHMIR', 'PUNJAB', 'CHANDIGARH', 'HARYANA', 'UTTAR PRADESH', 'UTTARAKHAND']
# ['JAMMU AND KASHMIR', 'PUNJAB', 'CHANDIGARH', 'HARYANA', 'UTTAR PRADESH', 'UTTARAKHAND']
# [829109, 3743486, 260786, 3626260, 14412965, 1624197]
# ['UTTARAKHAND', 'UTTAR PRADESH', 'HARYANA', 'CHANDIGARH', 'PUNJAB', 'JAMMU AND KASHMIR']
# ['UTTARAKHAND', 'UTTAR PRADESH', 'HARYANA', 'CHANDIGARH', 'PUNJAB', 'JAMMU AND KASHMIR']
# [1624197, 14412965, 3626260, 260786, 3743486, 829109]
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# [1624197, 14412965, 2600912]
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# [7219526, 3626260, 2600912]
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# [2600912, 14412965, 1624197]
# ['HIMACHAL PRADESH', 'PUNJAB', 'CHANDIGARH', 'HARYANA', 'DELHI NCT']
# ['HIMACHAL PRADESH', 'PUNJAB', 'CHANDIGARH', 'HARYANA', 'DELHI NCT']
# [921080, 3743486, 260786, 3626260, 2600912]
# ['DELHI NCT', 'HARYANA', 'CHANDIGARH', 'PUNJAB', 'HIMACHAL PRADESH']
# ['DELHI NCT', 'HARYANA', 'CHANDIGARH', 'PUNJAB', 'HIMACHAL PRADESH']
# [2600912, 3626260, 260786, 3743486, 921080]
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# [1624197, 14412965, 2600912]
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# [2600912, 14412965, 1624197]
# ['TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# ['TAMIL NADU', 'ANDHRA PRADESH', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# [10526724, 11096243, 20620198, 7947991, 14412965, 2600912]
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU']
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'ANDHRA PRADESH', 'TAMIL NADU']
# [2600912, 14412965, 7947991, 20620198, 11096243, 10526724]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'DELHI NCT']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'DELHI NCT']
# [20620198, 9521542, 7947991, 7219526, 2600912]
# ['DELHI NCT', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# ['DELHI NCT', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# [2600912, 7219526, 7947991, 9521542, 20620198]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['GOA', 'MAHARASHTRA', 'GUJARAT', 'RAJASTHAN', 'DELHI NCT']
# ['GOA', 'MAHARASHTRA', 'GUJARAT', 'RAJASTHAN', 'DELHI NCT']
# [435131, 20620198, 9521542, 7219526, 2600912]
# ['DELHI NCT', 'RAJASTHAN', 'GUJARAT', 'MAHARASHTRA', 'GOA']
# ['DELHI NCT', 'RAJASTHAN', 'GUJARAT', 'MAHARASHTRA', 'GOA']
# [2600912, 7219526, 9521542, 20620198, 435131]
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT', 'RAJASTHAN']
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT', 'RAJASTHAN']
# [1624197, 14412965, 2600912, 7219526]
# ['RAJASTHAN', 'UTTAR PRADESH', 'DELHI NCT', 'UTTARAKHAND']
# ['RAJASTHAN', 'UTTAR PRADESH', 'DELHI NCT', 'UTTARAKHAND']
# [7219526, 14412965, 2600912, 1624197]
# ['UTTAR PRADESH', 'MADHYA PRADESH']
# ['UTTAR PRADESH', 'MADHYA PRADESH']
# [14412965, 7947991]
# ['BIHAR', 'UTTAR PRADESH']
# ['BIHAR', 'UTTAR PRADESH']
# [6909439, 14412965]
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'UTTAR PRADESH']
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'UTTAR PRADESH']
# [829109, 3743486, 3626260, 14412965]
# ['MADHYA PRADESH', 'UTTAR PRADESH']
# ['MADHYA PRADESH', 'UTTAR PRADESH']
# [7947991, 14412965]
# ['UTTAR PRADESH', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# ['UTTAR PRADESH', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# [14412965, 3626260, 3743486, 829109]
# ['RAJASTHAN', 'UTTAR PRADESH']
# ['RAJASTHAN', 'UTTAR PRADESH']
# [7219526, 14412965]
# ['DELHI NCT', 'UTTAR PRADESH']
# ['DELHI NCT', 'UTTAR PRADESH']
# [2600912, 14412965]
# ['UTTAR PRADESH', 'DELHI NCT']
# ['UTTAR PRADESH', 'DELHI NCT']
# [14412965, 2600912]
# ['UTTAR PRADESH', 'BIHAR']
# ['UTTAR PRADESH', 'BIHAR']
# [14412965, 6909439]
# ['BIHAR', 'UTTAR PRADESH']
# ['BIHAR', 'UTTAR PRADESH']
# [6909439, 14412965]
# ['UTTAR PRADESH', 'RAJASTHAN']
# ['UTTAR PRADESH', 'RAJASTHAN']
# [14412965, 7219526]
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# [2600912, 14412965, 1624197]
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# [1624197, 14412965, 2600912]
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# ['DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# [2600912, 14412965, 1624197]
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT']
# [1624197, 14412965, 2600912]
# ['UTTAR PRADESH', 'UTTARAKHAND']
# ['UTTAR PRADESH', 'UTTARAKHAND']
# [14412965, 1624197]
# ['UTTARAKHAND', 'UTTAR PRADESH']
# ['UTTARAKHAND', 'UTTAR PRADESH']
# [1624197, 14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH', 'BIHAR']
# ['UTTAR PRADESH', 'BIHAR']
# [14412965, 6909439]
# ['BIHAR', 'UTTAR PRADESH']
# ['BIHAR', 'UTTAR PRADESH']
# [6909439, 14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTAR PRADESH']
# ['UTTAR PRADESH']
# [14412965]
# ['UTTARAKHAND', 'UTTAR PRADESH']
# ['UTTARAKHAND', 'UTTAR PRADESH']
# [1624197, 14412965]
# ['UTTARAKHAND', 'UTTAR PRADESH']
# ['UTTARAKHAND', 'UTTAR PRADESH']
# [1624197, 14412965]
# ['KARNATAKA', 'TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR']
# ['KARNATAKA', 'TAMIL NADU', 'ANDHRA PRADESH', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR']
# [9197706, 10526724, 11096243, 20620198, 7947991, 14412965, 6909439]
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KARNATAKA']
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KARNATAKA']
# [6909439, 14412965, 7947991, 20620198, 11096243, 10526724, 9197706]
# ['GUJARAT', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# ['GUJARAT', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# [9521542, 7219526, 14412965, 6909439]
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'GUJARAT']
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'GUJARAT']
# [6909439, 14412965, 7219526, 9521542]
# ['BIHAR', 'JHARKHAND', 'WEST BENGAL']
# ['BIHAR', 'JHARKHAND', 'WEST BENGAL']
# [6909439, 2999009, 8933321]
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR']
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR']
# [8933321, 2999009, 6909439]
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR']
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR']
# [20620198, 7947991, 14412965, 6909439]
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# [6909439, 14412965, 7947991, 20620198]
# ['WEST BENGAL', 'BIHAR']
# ['WEST BENGAL', 'BIHAR']
# [8933321, 6909439]
# ['BIHAR', 'WEST BENGAL']
# ['BIHAR', 'WEST BENGAL']
# [6909439, 8933321]
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR']
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR']
# [2600912, 14412965, 6909439]
# ['BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# ['BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# [6909439, 14412965, 2600912]
# ['WEST BENGAL', 'JHARKHAND', 'ODISHA', 'CHHATTISGARH', 'MAHARASHTRA', 'GUJARAT']
# ['WEST BENGAL', 'JHARKHAND', 'ODISHA', 'CHHATTISGARH', 'MAHARASHTRA', 'GUJARAT']
# [8933321, 2999009, 4454572, 3002954, 20620198, 9521542]
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# [2600912, 14412965, 7947991, 20620198]
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# [20620198, 7947991, 14412965, 2600912]
# ['PUNJAB', 'HARYANA', 'DELHI NCT', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'MAHARASHTRA']
# ['PUNJAB', 'HARYANA', 'DELHI NCT', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'MAHARASHTRA']
# [3743486, 3626260, 2600912, 14412965, 7219526, 7947991, 20620198]
# ['MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND']
# ['MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND']
# [20620198, 3002954, 4454572, 2999009]
# ...
# ['TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA', 'MAHARASHTRA']
# ['TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA', 'MAHARASHTRA']
# [10526724, 11096243, 9197706, 20620198]
# ['MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA']
# ['MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA']
# [20620198, 435131, 9197706, 6010350]
# ['KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA']
# ['KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA']
# [6010350, 9197706, 435131, 20620198]
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN', 'GUJARAT', 'MAHARASHTRA']
# ['DELHI NCT', 'HARYANA', 'RAJASTHAN', 'GUJARAT', 'MAHARASHTRA']
# [2600912, 3626260, 7219526, 9521542, 20620198]
# ['MAHARASHTRA', 'GUJARAT', 'RAJASTHAN', 'HARYANA', 'DELHI NCT']
# ['MAHARASHTRA', 'GUJARAT', 'RAJASTHAN', 'HARYANA', 'DELHI NCT']
# [20620198, 9521542, 7219526, 3626260, 2600912]
# ['GUJARAT', 'MAHARASHTRA']
# ['GUJARAT', 'MAHARASHTRA']
# [9521542, 20620198]
# ['MAHARASHTRA', 'GUJARAT']
# ['MAHARASHTRA', 'GUJARAT']
# [20620198, 9521542]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN']
# [20620198, 9521542, 7947991, 7219526]
# ['RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# ['RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# [7219526, 7947991, 9521542, 20620198]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH']
# [20620198, 9521542, 7947991]
# ['MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# ['MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# [7947991, 9521542, 20620198]
# ['MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA', 'KARNATAKA', 'TELANGANA']
# ['MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA', 'KARNATAKA', 'ANDHRA PRADESH']
# [7947991, 9521542, 20620198, 9197706, 11096243]
# ['TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA']
# ['TAMIL NADU', 'ANDHRA PRADESH']
# [10526724, 11096243]
# ['TELANGANA']
# ['ANDHRA PRADESH']
# [11096243]
# ['ANDHRA PRADESH', 'TAMIL NADU']
# ['ANDHRA PRADESH', 'TAMIL NADU']
# [11096243, 10526724]
# ['TAMIL NADU', 'ANDHRA PRADESH']
# ['TAMIL NADU', 'ANDHRA PRADESH']
# [10526724, 11096243]
# ['ANDHRA PRADESH']
# ['ANDHRA PRADESH']
# [11096243]
# ['ANDHRA PRADESH']
# ['ANDHRA PRADESH']
# [11096243]
# ['MAHARASHTRA', 'GUJARAT', 'RAJASTHAN']
# ['MAHARASHTRA', 'GUJARAT', 'RAJASTHAN']
# [20620198, 9521542, 7219526]
# ['WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# ['WEST BENGAL', 'BIHAR', 'UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA', 'PUNJAB', 'JAMMU AND KASHMIR']
# [8933321, 6909439, 14412965, 1624197, 3626260, 3743486, 829109]
# ['PUNJAB', 'HARYANA', 'UTTAR PRADESH', 'UTTARAKHAND']
# ['PUNJAB', 'HARYANA', 'UTTAR PRADESH', 'UTTARAKHAND']
# [3743486, 3626260, 14412965, 1624197]
# ['UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA', 'PUNJAB']
# ['UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA', 'PUNJAB']
# [14412965, 1624197, 3626260, 3743486]
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# [14412965, 7219526, 7947991, 6909439, 2999009, 8933321]
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'RAJASTHAN']
# ['WEST BENGAL', 'JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'RAJASTHAN']
# [8933321, 2999009, 6909439, 14412965, 7947991, 7219526]
# ['KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA', 'GUJARAT', 'RAJASTHAN', 'DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# ['KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA', 'GUJARAT', 'RAJASTHAN', 'DELHI NCT', 'UTTAR PRADESH', 'UTTARAKHAND']
# [6010350, 9197706, 435131, 20620198, 9521542, 7219526, 2600912, 14412965, 1624197]
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT', 'RAJASTHAN', 'GUJARAT', 'MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA']
# ['UTTARAKHAND', 'UTTAR PRADESH', 'DELHI NCT', 'RAJASTHAN', 'GUJARAT', 'MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA']
# [1624197, 14412965, 2600912, 7219526, 9521542, 20620198, 435131, 9197706, 6010350]
# ['TAMIL NADU']
# ['TAMIL NADU']
# [10526724]
# ['TAMIL NADU']
# ['TAMIL NADU']
# [10526724]
# ['KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA']
# ['KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA']
# [6010350, 9197706, 435131, 20620198]
# ['MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA']
# ['MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA']
# [20620198, 435131, 9197706, 6010350]
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'BIHAR', 'JHARKHAND', 'WEST BENGAL']
# [14412965, 7219526, 7947991, 6909439, 2999009, 8933321]
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'ANDHRA PRADESH', 'TAMIL NADU']
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'ANDHRA PRADESH', 'TAMIL NADU']
# [2600912, 14412965, 7947991, 20620198, 11096243, 10526724]
# ['TAMIL NADU', 'ANDHRA PRADESH', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# ['TAMIL NADU', 'ANDHRA PRADESH', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# [10526724, 11096243, 20620198, 7947991, 14412965, 2600912]
# ['TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA']
# ['TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA']
# [10526724, 11096243, 9197706]
# ['KARNATAKA', 'ANDHRA PRADESH', 'TAMIL NADU']
# ['KARNATAKA', 'ANDHRA PRADESH', 'TAMIL NADU']
# [9197706, 11096243, 10526724]
# ['PUDUCHERRY', 'TAMIL NADU', 'KERALA', 'KARNATAKA']
# ['PUDUCHERRY', 'TAMIL NADU', 'KERALA', 'KARNATAKA']
# [276741, 10526724, 6010350, 9197706]
# ['PUDUCHERRY', 'TAMIL NADU']
# ['PUDUCHERRY', 'TAMIL NADU']
# [276741, 10526724]
# ['TAMIL NADU', 'PUDUCHERRY']
# ['TAMIL NADU', 'PUDUCHERRY']
# [10526724, 276741]
# ['TAMIL NADU']
# ['TAMIL NADU']
# [10526724]
# ['TAMIL NADU']
# ['TAMIL NADU']
# [10526724]
# ['ODISHA']
# ['ODISHA']
# [4454572]
# ['ODISHA']
# ['ODISHA']
# [4454572]
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR']
# ['DELHI NCT', 'UTTAR PRADESH', 'BIHAR']
# [2600912, 14412965, 6909439]
# ['RAJASTHAN', 'GUJARAT']
# ['RAJASTHAN', 'GUJARAT']
# [7219526, 9521542]
# ['GUJARAT', 'RAJASTHAN']
# ['GUJARAT', 'RAJASTHAN']
# [9521542, 7219526]
# ['RAJASTHAN', 'GUJARAT']
# ['RAJASTHAN', 'GUJARAT']
# [7219526, 9521542]
# ['GUJARAT', 'RAJASTHAN']
# ['GUJARAT', 'RAJASTHAN']
# [9521542, 7219526]
# ['RAJASTHAN', 'HARYANA']
# ['RAJASTHAN', 'HARYANA']
# [7219526, 3626260]
# ['HARYANA', 'RAJASTHAN']
# ['HARYANA', 'RAJASTHAN']
# [3626260, 7219526]
# ['HARYANA', 'RAJASTHAN']
# ['HARYANA', 'RAJASTHAN']
# [3626260, 7219526]
# ['RAJASTHAN', 'PUNJAB']
# ['RAJASTHAN', 'PUNJAB']
# [7219526, 3743486]
# ['RAJASTHAN', 'HARYANA']
# ['RAJASTHAN', 'HARYANA']
# [7219526, 3626260]
# ['HARYANA', 'RAJASTHAN']
# ['HARYANA', 'RAJASTHAN']
# [3626260, 7219526]
# ['RAJASTHAN', 'PUNJAB']
# ['RAJASTHAN', 'PUNJAB']
# [7219526, 3743486]
# ['RAJASTHAN', 'HARYANA']
# ['RAJASTHAN', 'HARYANA']
# [7219526, 3626260]
# ['PUNJAB', 'RAJASTHAN']
# ['PUNJAB', 'RAJASTHAN']
# [3743486, 7219526]
# ['GUJARAT', 'RAJASTHAN']
# ['GUJARAT', 'RAJASTHAN']
# [9521542, 7219526]
# ['GUJARAT', 'MAHARASHTRA', 'KARNATAKA', 'ANDHRA PRADESH', 'TAMIL NADU']
# ['GUJARAT', 'MAHARASHTRA', 'KARNATAKA', 'ANDHRA PRADESH', 'TAMIL NADU']
# [9521542, 20620198, 9197706, 11096243, 10526724]
# ['TAMIL NADU']
# ['TAMIL NADU']
# [10526724]
# ['ANDHRA PRADESH', 'TAMIL NADU']
# ['ANDHRA PRADESH', 'TAMIL NADU']
# [11096243, 10526724]
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR']
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR']
# [6010350, 10526724, 11096243, 20620198, 7947991, 14412965, 6909439]
# ['TAMIL NADU', 'ANDHRA PRADESH']
# ['TAMIL NADU', 'ANDHRA PRADESH']
# [10526724, 11096243]
# ['TAMIL NADU', 'KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA', 'GUJARAT']
# ['TAMIL NADU', 'KERALA', 'KARNATAKA', 'GOA', 'MAHARASHTRA', 'GUJARAT']
# [10526724, 6010350, 9197706, 435131, 20620198, 9521542]
# ['GUJARAT', 'MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA', 'TAMIL NADU']
# ['GUJARAT', 'MAHARASHTRA', 'GOA', 'KARNATAKA', 'KERALA', 'TAMIL NADU']
# [9521542, 20620198, 435131, 9197706, 6010350, 10526724]
# ['MADHYA PRADESH', 'MAHARASHTRA', 'GUJARAT']
# ['MADHYA PRADESH', 'MAHARASHTRA', 'GUJARAT']
# [7947991, 20620198, 9521542]
# ['GUJARAT', 'MAHARASHTRA', 'MADHYA PRADESH']
# ['GUJARAT', 'MAHARASHTRA', 'MADHYA PRADESH']
# [9521542, 20620198, 7947991]
# ['RAJASTHAN', 'MADHYA PRADESH', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND', 'WEST BENGAL']
# ['RAJASTHAN', 'MADHYA PRADESH', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND', 'WEST BENGAL']
# [7219526, 7947991, 3002954, 4454572, 2999009, 8933321]
# ['WEST BENGAL', 'JHARKHAND', 'ODISHA', 'CHHATTISGARH', 'MADHYA PRADESH', 'RAJASTHAN']
# ['WEST BENGAL', 'JHARKHAND', 'ODISHA', 'CHHATTISGARH', 'MADHYA PRADESH', 'RAJASTHAN']
# [8933321, 2999009, 4454572, 3002954, 7947991, 7219526]
# ['GUJARAT', 'RAJASTHAN', 'UTTAR PRADESH']
# ['GUJARAT', 'RAJASTHAN', 'UTTAR PRADESH']
# [9521542, 7219526, 14412965]
# ['GUJARAT', 'RAJASTHAN', 'UTTAR PRADESH']
# ['GUJARAT', 'RAJASTHAN', 'UTTAR PRADESH']
# [9521542, 7219526, 14412965]
# ['GUJARAT', 'RAJASTHAN', 'HARYANA', 'DELHI NCT', 'UTTAR PRADESH']
# ['GUJARAT', 'RAJASTHAN', 'HARYANA', 'DELHI NCT', 'UTTAR PRADESH']
# [9521542, 7219526, 3626260, 2600912, 14412965]
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# ['KERALA', 'TAMIL NADU', 'ANDHRA PRADESH', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'DELHI NCT']
# [6010350, 10526724, 11096243, 20620198, 7947991, 14412965, 2600912]
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# ['DELHI NCT', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# [2600912, 14412965, 7947991, 20620198, 11096243, 10526724, 6010350]
# ['TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'RAJASTHAN', 'HARYANA', 'DELHI NCT', 'PUNJAB', 'JAMMU AND KASHMIR']
# ['TAMIL NADU', 'ANDHRA PRADESH', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'RAJASTHAN', 'HARYANA', 'DELHI NCT', 'PUNJAB', 'JAMMU AND KASHMIR']
# [10526724, 11096243, 20620198, 7947991, 14412965, 7219526, 3626260, 2600912, 3743486, 829109]
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'DELHI NCT', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU']
# ['JAMMU AND KASHMIR', 'PUNJAB', 'HARYANA', 'DELHI NCT', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'MAHARASHTRA', 'ANDHRA PRADESH', 'TAMIL NADU']
# [829109, 3743486, 3626260, 2600912, 14412965, 7219526, 7947991, 20620198, 11096243, 10526724]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['KARNATAKA']
# ['KARNATAKA']
# [9197706]
# ['TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA']
# ['TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA']
# [10526724, 11096243, 9197706]
# ['KARNATAKA']
# ['KARNATAKA']
# [9197706]
# ['KARNATAKA']
# ['KARNATAKA']
# [9197706]
# ['KARNATAKA']
# ['KARNATAKA']
# [9197706]
# ['KARNATAKA']
# ['KARNATAKA']
# [9197706]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['MADHYA PRADESH']
# ['MADHYA PRADESH']
# [7947991]
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# ['RAJASTHAN', 'HARYANA', 'DELHI NCT']
# [7219526, 3626260, 2600912]
# ['PUDUCHERRY', 'TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA', 'MAHARASHTRA']
# ['PUDUCHERRY', 'TAMIL NADU', 'ANDHRA PRADESH', 'KARNATAKA', 'MAHARASHTRA']
# [276741, 10526724, 11096243, 9197706, 20620198]
# ['MAHARASHTRA', 'KARNATAKA', 'ANDHRA PRADESH', 'TAMIL NADU', 'PUDUCHERRY']
# ['MAHARASHTRA', 'KARNATAKA', 'ANDHRA PRADESH', 'TAMIL NADU', 'PUDUCHERRY']
# [20620198, 9197706, 11096243, 10526724, 276741]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['RAJASTHAN']
# ['RAJASTHAN']
# [7219526]
# ['JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# ['JHARKHAND', 'BIHAR', 'UTTAR PRADESH', 'DELHI NCT']
# [2999009, 6909439, 14412965, 2600912]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# [20620198, 9521542, 7947991, 7219526, 14412965]
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR', 'WEST BENGAL', 'ASSAM']
# [20620198, 7947991, 14412965, 6909439, 8933321, 2896119]
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# [6909439, 14412965, 7219526, 7947991, 9521542, 20620198]
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# ['UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# [14412965, 7219526, 7947991, 9521542, 20620198]
# ['TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL']
# ['TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL']
# [10526724, 11096243, 4454572, 8933321]
# ['WEST BENGAL', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU']
# ['WEST BENGAL', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU']
# [8933321, 4454572, 11096243, 10526724]
# ['TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL']
# ['TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL']
# [10526724, 11096243, 4454572, 8933321]
# ['TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'RAJASTHAN']
# ['TAMIL NADU', 'ANDHRA PRADESH', 'MAHARASHTRA', 'MADHYA PRADESH', 'RAJASTHAN']
# [10526724, 11096243, 20620198, 7947991, 7219526]
# ['RAJASTHAN', 'MADHYA PRADESH', 'MAHARASHTRA', 'TELANGANA', 'ANDHRA PRADESH', 'TAMIL NADU']
# ['RAJASTHAN', 'MADHYA PRADESH', 'MAHARASHTRA', 'ANDHRA PRADESH', 'TAMIL NADU']
# [7219526, 7947991, 20620198, 11096243, 10526724]
# ['MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND']
# ['MAHARASHTRA', 'CHHATTISGARH', 'ODISHA', 'JHARKHAND']
# [20620198, 3002954, 4454572, 2999009]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH']
# [20620198, 9521542, 7947991, 7219526, 14412965]
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# [20620198, 7947991, 14412965]
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# [20620198, 7947991, 14412965]
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# ['MAHARASHTRA', 'GUJARAT', 'MADHYA PRADESH', 'RAJASTHAN', 'UTTAR PRADESH', 'BIHAR']
# [20620198, 9521542, 7947991, 7219526, 14412965, 6909439]
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# ['BIHAR', 'UTTAR PRADESH', 'RAJASTHAN', 'MADHYA PRADESH', 'GUJARAT', 'MAHARASHTRA']
# [6909439, 14412965, 7219526, 7947991, 9521542, 20620198]
# ['KARNATAKA', 'TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL']
# ['KARNATAKA', 'TAMIL NADU', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL']
# [9197706, 10526724, 11096243, 4454572, 8933321]
# ['WEST BENGAL', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KARNATAKA']
# ['WEST BENGAL', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KARNATAKA']
# [8933321, 4454572, 11096243, 10526724, 9197706]
# ['KARNATAKA', 'TAMIL NADU', 'ANDHRA PRADESH', 'TELANGANA', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR']
# ['KARNATAKA', 'TAMIL NADU', 'ANDHRA PRADESH', 'MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH', 'BIHAR']
# [9197706, 10526724, 11096243, 20620198, 7947991, 14412965, 6909439]
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# ['BIHAR', 'UTTAR PRADESH', 'MADHYA PRADESH', 'MAHARASHTRA']
# [6909439, 14412965, 7947991, 20620198]
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# ['MAHARASHTRA', 'MADHYA PRADESH', 'UTTAR PRADESH']
# [20620198, 7947991, 14412965]
# ['KARNATAKA', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL', 'JHARKHAND', 'BIHAR']
# ['KARNATAKA', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL', 'JHARKHAND', 'BIHAR']
# [9197706, 11096243, 4454572, 8933321, 2999009, 6909439]
# ['TRIPURA', 'ASSAM', 'WEST BENGAL', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# ['TRIPURA', 'ASSAM', 'WEST BENGAL', 'ODISHA', 'ANDHRA PRADESH', 'TAMIL NADU', 'KERALA']
# [354081, 2896119, 8933321, 4454572, 11096243, 10526724, 6010350]
# ['KARNATAKA', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL', 'ASSAM']
# ['KARNATAKA', 'ANDHRA PRADESH', 'ODISHA', 'WEST BENGAL', 'ASSAM']
# [9197706, 11096243, 4454572, 8933321, 2896119]

# %%
f=[2896119, 8933321, 6909439, 14412965, 2600912, 3626260, 7219526]
[sum(f[(i):len(f)]) for i in range(len(y))]
# Out:
# [46598542, 43702423, 34769102, 27859663, 13446698]

# %%
dfG["RAJASTHAN"]["HIMACHAL PRADESH"]
# Out:
# 15649

# %%
dfG
# Out:
#                            HIMACHAL PRADESH   PUNJAB  CHANDIGARH  UTTARAKHAND  \
# HIMACHAL PRADESH                          0   876030        6260            0
# PUNJAB                               387622        0       50902       219179
# CHANDIGARH                            14078     9135           0        17576
# UTTARAKHAND                               0    44645       47143            0
# HARYANA                             1202021  2856950      259586       397020
# RAJASTHAN                             70636  2020228        2270       278152
# UTTAR PRADESH                             0   709831      449261      5717862
# BIHAR                                     0   125682       43325       308428
# ARUNACHAL PRADESH                         0        0           0            0
# NAGALAND                                  0        0         520            0
# MANIPUR                                   0        0           0            0
# MIZORAM                                   0        0           0            0
# TRIPURA                                   0        0           0            0
# MEGHALAYA                                 0        0           0            0
# ASSAM                                     0        0        5915            0
# WEST BENGAL                               0    42764       18246       314461
# JHARKHAND                                 0    14356           0       105565
# ODISHA                                    0        0           0        23064
# CHHATTISGARH                              0    11057           0        15548
# MADHYA PRADESH                            0   108680           0        57467
# GUJARAT                                   0     6416           0        10167
# DAMAN & DIU                               0        0           0            0
# DADRA & NAGAR HAVELI                      0        0           0            0
# MAHARASHTRA                               0   255638           0        22019
# ANDHRA PRADESH                            0      174           0            0
# KARNATAKA                                 0       73           0         1565
# GOA                                       0        0           0           74
# LAKSHADWEEP                               0        0           0            0
# KERALA                                    0        0           0         1022
# TAMIL NADU                                0       81           0            0
# PUDUCHERRY                                0        0           0            0
# ANDAMAN & NICOBAR ISLANDS                 0        0           0            0
# DELHI NCT                            243866  1043739      179759       625648
# JAMMU AND KASHMIR                         0  2876013        4730        21505
# SIKKIM                                    0        0           0            0
#
#                            HARYANA  RAJASTHAN  UTTAR PRADESH    BIHAR  \
# HIMACHAL PRADESH            777098      15649              0        0
# PUNJAB                     3092149    2010875         841475    90130
# CHANDIGARH                 1717548       4430          41264     2434
# UTTARAKHAND                  94882      95600        6772337    70319
# HARYANA                          0    5116465        1994972   117414
# RAJASTHAN                  3193698          0        2294727   161214
# UTTAR PRADESH              1004723    1993843              0  5090480
# BIHAR                        36607     238120        5431461        0
# ARUNACHAL PRADESH                0          0              0        0
# NAGALAND                        56          0            437      616
# MANIPUR                          0          0              0        0
# MIZORAM                          0          0              0        0
# TRIPURA                          0          0            601    19547
# MEGHALAYA                        0          0              0        0
# ASSAM                         1231      20456          65669   603625
# WEST BENGAL                  31316     312633         830010  3736043
# JHARKHAND                     8619      78184         290244  3972661
# ODISHA                        3498      34442          68136   224591
# CHHATTISGARH                  3744      26890          59962    67057
# MADHYA PRADESH               17195    1622711        4008007   622166
# GUJARAT                      56807     681989         198486   153775
# DAMAN & DIU                      0          0              0        0
# DADRA & NAGAR HAVELI             0          0              0        0
# MAHARASHTRA                  77939    1063498        1502974   608963
# ANDHRA PRADESH                 185      38623         147370   132873
# KARNATAKA                     8205       1664          38211    18479
# GOA                            384        395            159        0
# LAKSHADWEEP                      0          0              0        0
# KERALA                        5310       1087           2847     8359
# TAMIL NADU                    9387      37834          58681    57134
# PUDUCHERRY                       0          0              0        0
# ANDAMAN & NICOBAR ISLANDS        0          0              0        0
# DELHI NCT                  6120194    2224344        8168365   209403
# JAMMU AND KASHMIR           245055      34425         120291     6562
# SIKKIM                           0          0              0        0
#
#                            ARUNACHAL PRADESH  NAGALAND  ...  KARNATAKA  \
# HIMACHAL PRADESH                           0         0  ...          0
# PUNJAB                                     0         0  ...        116
# CHANDIGARH                                 0         4  ...          0
# UTTARAKHAND                                0         0  ...         50
# HARYANA                                    0        59  ...        112
# RAJASTHAN                                  0         0  ...        458
# UTTAR PRADESH                              0       239  ...     133564
# BIHAR                                      0       118  ...      24679
# ARUNACHAL PRADESH                          0         0  ...          0
# NAGALAND                                   0         0  ...          0
# MANIPUR                                    0         0  ...          0
# MIZORAM                                    0         0  ...          0
# TRIPURA                                    0         0  ...        195
# MEGHALAYA                                  0         0  ...          0
# ASSAM                                      0         0  ...       2861
# WEST BENGAL                                0       159  ...     135066
# JHARKHAND                                  0         0  ...      14228
# ODISHA                                     0         0  ...      95557
# CHHATTISGARH                               0         0  ...         26
# MADHYA PRADESH                             0         0  ...      76829
# GUJARAT                                    0         0  ...      18453
# DAMAN & DIU                                0         0  ...          0
# DADRA & NAGAR HAVELI                       0         0  ...          0
# MAHARASHTRA                                0         0  ...    1735131
# ANDHRA PRADESH                             0         0  ...    2766495
# KARNATAKA                                  0         0  ...          0
# GOA                                        0         0  ...     206875
# LAKSHADWEEP                                0         0  ...          0
# KERALA                                     0         0  ...     481079
# TAMIL NADU                                 0         0  ...    1315571
# PUDUCHERRY                                 0         0  ...        449
# ANDAMAN & NICOBAR ISLANDS                  0         0  ...          0
# DELHI NCT                                  0         0  ...      14712
# JAMMU AND KASHMIR                          0         0  ...         25
# SIKKIM                                     0         0  ...          0
#
#                                GOA  LAKSHADWEEP  KERALA  TAMIL NADU  \
# HIMACHAL PRADESH                 0            0       0           0
# PUNJAB                           0            0       0         718
# CHANDIGARH                       0            0       0           0
# UTTARAKHAND                      2            0     311           0
# HARYANA                          0            0       0         696
# RAJASTHAN                    21051            0    2945       34304
# UTTAR PRADESH                10451            0   26055      114233
# BIHAR                          165            0    9252       28648
# ARUNACHAL PRADESH                0            0       0           0
# NAGALAND                         0            0       0           4
# MANIPUR                          0            0       0           0
# MIZORAM                          0            0       0           0
# TRIPURA                          0            0       0          59
# MEGHALAYA                        0            0       0           0
# ASSAM                            0            0     360        7006
# WEST BENGAL                  18814            0    3425      178751
# JHARKHAND                       45            0       0       15960
# ODISHA                        9381            0    1707      160893
# CHHATTISGARH                     0            0    2932        6152
# MADHYA PRADESH                5944            0   28544       93695
# GUJARAT                      33911            0   58758       42377
# DAMAN & DIU                      0            0       0           0
# DADRA & NAGAR HAVELI             0            0       0           0
# MAHARASHTRA                1449584            0  225865      486987
# ANDHRA PRADESH               72301            0  254610     1149606
# KARNATAKA                   105735            0  424445     1297417
# GOA                              0            0    3069        1063
# LAKSHADWEEP                      0            0       0           0
# KERALA                        3810            0       0      816551
# TAMIL NADU                    1244            0  506675           0
# PUDUCHERRY                       0            0     224      424564
# ANDAMAN & NICOBAR ISLANDS        0            0       0           0
# DELHI NCT                     9436            0    1473       10003
# JAMMU AND KASHMIR                0            0       0         159
# SIKKIM                           0            0       0           0
#
#                            PUDUCHERRY  ANDAMAN & NICOBAR ISLANDS  DELHI NCT  \
# HIMACHAL PRADESH                    0                          0     103591
# PUNJAB                              0                          0    2316268
# CHANDIGARH                          0                          0      84998
# UTTARAKHAND                         0                          0     765597
# HARYANA                             0                          0    3827052
# RAJASTHAN                           0                          0    2770541
# UTTAR PRADESH                       0                          0    7474747
# BIHAR                               0                          0     529502
# ARUNACHAL PRADESH                   0                          0          0
# NAGALAND                            0                          0          0
# MANIPUR                             0                          0          0
# MIZORAM                             0                          0          0
# TRIPURA                             0                          0          0
# MEGHALAYA                           0                          0          0
# ASSAM                               0                          0      43742
# WEST BENGAL                     13409                          0     243806
# JHARKHAND                           0                          0      40867
# ODISHA                          16527                          0      44160
# CHHATTISGARH                        0                          0      51376
# MADHYA PRADESH                      0                          0     633279
# GUJARAT                             0                          0     212121
# DAMAN & DIU                         0                          0          0
# DADRA & NAGAR HAVELI                0                          0          0
# MAHARASHTRA                      4823                          0     726088
# ANDHRA PRADESH                  43764                          0     178233
# KARNATAKA                       11080                          0      60025
# GOA                                 0                          0       1757
# LAKSHADWEEP                         0                          0          0
# KERALA                           5834                          0       2043
# TAMIL NADU                      64606                          0      35038
# PUDUCHERRY                          0                          0          0
# ANDAMAN & NICOBAR ISLANDS           0                          0          0
# DELHI NCT                           0                          0          0
# JAMMU AND KASHMIR                   0                          0     187583
# SIKKIM                              0                          0          0
#
#                            JAMMU AND KASHMIR  SIKKIM
# HIMACHAL PRADESH                           0       0
# PUNJAB                                902565       0
# CHANDIGARH                              5342       0
# UTTARAKHAND                            38243       0
# HARYANA                               747173       0
# RAJASTHAN                             184260       0
# UTTAR PRADESH                         878366       0
# BIHAR                                  59058       0
# ARUNACHAL PRADESH                          0       0
# NAGALAND                                   0       0
# MANIPUR                                    0       0
# MIZORAM                                    0       0
# TRIPURA                                    0       0
# MEGHALAYA                                  0       0
# ASSAM                                      0       0
# WEST BENGAL                            38683       0
# JHARKHAND                              12986       0
# ODISHA                                     0       0
# CHHATTISGARH                            4862       0
# MADHYA PRADESH                         15329       0
# GUJARAT                                41158       0
# DAMAN & DIU                                0       0
# DADRA & NAGAR HAVELI                       0       0
# MAHARASHTRA                            33274       0
# ANDHRA PRADESH                          3435       0
# KARNATAKA                               1370       0
# GOA                                        0       0
# LAKSHADWEEP                                0       0
# KERALA                                     0       0
# TAMIL NADU                              1690       0
# PUDUCHERRY                                 0       0
# ANDAMAN & NICOBAR ISLANDS                  0       0
# DELHI NCT                             462354       0
# JAMMU AND KASHMIR                          0       0
# SIKKIM                                     0       0
#
# [35 rows x 35 columns]

# %%
G=nx.from_pandas_adjacency(dfG)
nx.write_gml(G,"Post_Cov_Mig_T.gml")
nx.draw_networkx(G)

# %%
df1 = pd.read_csv('Statelatlong.csv',header = None , names =['node', 'latitude', 'longitude'])
lis=[]
for ind in df1.index:
    df1.loc[ind, ('node')]=df1['node'][ind].upper()
    
    lis.append(df1['node'][ind].upper())
lis
lis2=list(G.nodes())
for i in list(G.nodes()):
    temp=df1.loc[df1['node'] == i]
    try:
        G.nodes[i]["longitude"]=temp.iloc[0]["longitude"]
        G.nodes[i]["latitude"]=temp.iloc[0]["latitude"]
    except:
        pass

# %%
G.nodes.data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-fb753b653a72> in <module>
# ----> 1 G.nodes.data()
#
# NameError: name 'G' is not defined

# %%
nx.write_gml(G,"Post_Cov_Mig_T.gml")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-09f1ea5ed268> in <module>
# ----> 1 len(list(G.edges()))
#
# NameError: name 'G' is not defined
