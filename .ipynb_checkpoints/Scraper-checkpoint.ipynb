# %%
import requests
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd

# %%
r = requests.get('https://indiarailinfo.com/trains/special/0/xx?i=1&pt=0&tt=33')
print(r.content)
# Out:
# b'{"ButtonContent":"<div style=\\"margin-top:10px;\\"><button class=\\"nextbtn\\" onclick=\\"javascript:getNextTrainListPageBare($(this).parent(),\'/trains/special/0/1?i=1&i=1&pt=0&tt=33\');\\"><div>NEXT PAGE<br />the next 50 Trains will appear below<\\/div><\\/button><\\/div>","TableContent":"<div style=\\"line-height:20px;\\"><div class=\\"\\" style=\\"width:60px;background-color:#C8C3FF;color:#D40000;border-bottom:1px solid #D40000;\\" >02406<\\/div><div class=\\"\\" style=\\"width:300px;background-color:#C8C3FF;color:#D40000;border-bottom:1px solid #D40000;\\" >Hatia - Mumbai CSMT SF Special Fare Special<\\/div><div class=\\"\\" style=\\"width:40px;background-color:#C8C3FF;color:#D40000;border-bottom:1px solid #D40000;\\" >COVR<\\/div><div style=\\"width:40px;\\" class=\\"\\">CR<\\/div><div style=\\"width:120px;\\" class=\\"\\"><b class=\\"greenColor\\">Src/Dest Changed.<\\/b><\\/div><div style=\\"width:70px;\\" class=\\"\\"><span class=\\"ontime greenColor\\">Jun 11<\\/span><\\/div><div style=\\"width:70px;\\" class=\\"\\"><span class=\\"delayed redColor\\">Jun 25<\\/span><\\/div><div style=\\"width:40px;\\" class=\\"\\">HTE<\\/div><div style=\\"width:60px;\\" class=\\"\\">17:40<\\/div><div style=\\"width:40px;\\" class=\\"\\">CSMT<\\/div><div style=\\"width:60px;\\" class=\\"\\">23:00<\\/div><div style=\\"width:70px;\\" class=\\"\\">29h 20m<\\/div><div style=\\"width:40px;\\" class=\\"\\">13<\\/div><div style=\\"width:120px;\\" class=\\"\\"><table style=\\"margin:auto;\\" class=\\"deparrgrid ltGrayColor brownColor\\"><tr><td>&#160;<\\/td><td>&#160;<\\/td><td>&#160;<\\/td><td>&#160;<\\/td><td>&#160;<\\/td><td>F<\\/td><td>&#160;<\\/td><\\/tr><\\/table><\\/div><div style=\\"width:70px;\\" class=\\"\\">2S SL <\\/div><div style=\\"width:60px;\\" class=\\"\\">1716 km<\\/div><div style=\\"width:60px;\\" class=\\"\\">58 km/hr<\\/div><div style=\\"width:50px;\\" class=\\"\\">02405<\\/div><\\/div><div class=\\"reg trnsumm\\" t=14325 ofs=385 fs=385 ots=12282 ts=12282 ><\\/div><div style=\\"line-height:20px;\\"><div class=\\"\\" style=\\"width:60px;background-color:#C8C3FF;color:#D40000;border-bottom:1px solid #D40000;\\" >07052<\\/div><div class=\\"\\" style=\\"width:300px;background-color:#C8C3FF;color:#D40000;border-bottom:1px solid #D40000;\\" >Chhapra - Secunderabad Summer Special Fare Special<\\/div><div class=\\"\\" style=\\"width:40px;background-color:#C8C3FF;color:#D40000;border-bottom:1px solid #D40000;\\" >COVR<\\/div><div style=\\"width:40px;\\" class=\\"\\">SCR<\\/div><div style=\\"width:120px;\\" class=\\"\\"><b class=\\"greenColor\\">No TT Change<\\/b><\\/div><div style=\\"width:70px;\\" class=\\"\\"><span class=\\"ontime greenColor\\">Jun 08<\\/span><\\/div><div style=\\"width:70px;\\" class=\\"\\"><span class=\\"delayed redColor\\">Jun 29<\\/span><\\/div><div style=\\"width:40px;\\" class=\\"\\">CPR<\\/div><div style=\\"width:60px;\\" class=\\"\\">23:30<\\/div><div style=\\"width:40px;\\" class=\\"\\">SC<\\/div><div style=\\"width:60px;\\" class=\\"\\">17:15<\\/div><div style=\\"width:70px;\\" class=\\"\\">41h 45m<\\/div><div style=\\"width:40px;\\" class=\\"\\">20<\\/div><div style=\\"width:120px;\\" class=\\"\\"><table style=\\"margin:auto;\\" class=\\"deparrgrid ltGrayColor brownColor\\"><tr><td>&#160;<\\/td><td>&#160;<\\/td><td>T<\\/td><td>&#160;<\\/td><td>&#160;<\\/td><td>&#160;<\\/td><td>&#160;<\\/td><\\/tr><\\/table><\\/div><div style=\\"width:70px;\\" class=\\"\\">2S SL 3A <\\/div><div style=\\"width:60px;\\" class=\\"\\">2075 km<\\/div><div style=\\"width:60px;\\" class=\\"\\">50 km/hr<\\/div><div style=\\"width:50px;\\" class=\\"\\">07051<\\/div><\\/div><div class=\\"reg trnsumm\\" t=147770 ofs=691 fs=691 ots=835 ts=835 ><\\/div><div style=\\"line-height:20px;\\"><div class=\\"\\" style=\\"width:60px;background-color:#C8C3FF;color:#D40000;border-bottom:1px solid #D40000;\\" >02405<\\/div><div class=\\"\\" style=\\"width:300px;background-color:#C8C3FF;color:#D40000;border-bottom:1px solid #D40000;\\" >Mumba ...

# %%
soup = BeautifulSoup(r.content, 'html.parser')
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3e7fa4e6c87f> in <module>
# ----> 1 soup = BeautifulSoup(r.content, 'html.parser')
#       2 print(soup.prettify())
#
# NameError: name 'BeautifulSoup' is not defined

# %%
soup = BeautifulSoup(r.content, 'html.parser')
data = []
table = soup.find('table', attrs={'class':'lineItemsTable'})


rows = soup.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele])

# %%
data[6]
# Out:
# ['No. of Persons', 'Percentage', 'No. of Persons', 'Percentage']

# %%
pov_df = pd.DataFrame(columns=['State_Name', 'Poverty'])
dic={}
itr=47
lenn=len(data)
print(lenn)
#for i in range(5)
while itr<47+35:
    lis=[]
    lis.append(data[itr][0].upper())
    lis.append(float(data[itr][6]))
    pov_df.loc[len(pov_df)]=lis
    dic[data[itr][0].upper()]=float(data[itr][6])
    itr+=1
pov_df.loc[28,"State_Name"]="ANDAMAN & NICOBAR ISLANDS"
pov_df.loc[9,"State_Name"]="JAMMU & KASHMIR"
pov_df.loc[31,"State_Name"]="NCT OF DELHI"
dic["NCT OF DELHI"]=dic["DELHI"]
dic["JAMMU & KASHMIR"]=dic["JAMMU AND KASHMIR"]
dic["ANDAMAN & NICOBAR ISLANDS"]=dic["ANDAMAN AND NICOBAR ISLANDS"]

pov_df
# Out:
# 84
#                    State_Name  Poverty
# 0              ANDHRA PRADESH      9.2
# 1           ARUNACHAL PRADESH     34.7
# 2                       ASSAM     32.0
# 3                       BIHAR     33.7
# 4                CHHATTISGARH     39.9
# 5                         GOA      5.1
# 6                     GUJARAT     16.6
# 7                     HARYANA     11.2
# 8            HIMACHAL PRADESH      8.1
# 9             JAMMU & KASHMIR     10.4
# 10                  JHARKHAND     37.0
# 11                  KARNATAKA     20.9
# 12                     KERALA      7.1
# 13             MADHYA PRADESH     31.7
# 14                MAHARASHTRA     17.4
# 15                    MANIPUR     36.9
# 16                  MEGHALAYA     11.9
# 17                    MIZORAM     20.4
# 18                   NAGALAND     18.9
# 19                     ODISHA     32.6
# 20                     PUNJAB      8.3
# 21                  RAJASTHAN     14.7
# 22                     SIKKIM      8.2
# 23                 TAMIL NADU     11.3
# 24                    TRIPURA     14.1
# 25                UTTARAKHAND     11.3
# 26              UTTAR PRADESH     29.4
# 27                WEST BENGAL     20.0
# 28  ANDAMAN & NICOBAR ISLANDS      1.0
# 29                 CHANDIGARH     21.8
# 30       DADRA & NAGAR HAVELI     39.3
# 31               NCT OF DELHI      9.9
# 32                DAMAN & DIU      9.9
# 33                LAKSHADWEEP      2.8
# 34                 PUDUCHERRY      9.7

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G=nx.read_gml("2011.gml")
G.remove_edges_from(nx.selfloop_edges(G))

# %%
bins=[]
temp=-25.5
while temp<26:
    bins.append(temp)
    temp+=1
bins
# Out:
# [-25.5,
#  -24.5,
#  -23.5,
#  -22.5,
#  -21.5,
#  -20.5,
#  -19.5,
#  -18.5,
#  -17.5,
#  -16.5,
#  -15.5,
#  -14.5,
#  -13.5,
#  -12.5,
#  -11.5,
#  -10.5,
#  -9.5,
#  -8.5,
#  -7.5,
#  -6.5,
#  -5.5,
#  -4.5,
#  -3.5,
#  -2.5,
#  -1.5,
#  -0.5,
#  0.5,
#  1.5,
#  2.5,
#  3.5,
#  4.5,
#  5.5,
#  6.5,
#  7.5,
#  8.5,
#  9.5,
#  10.5,
#  11.5,
#  12.5,
#  13.5,
#  14.5,
#  15.5,
#  16.5,
#  17.5,
#  18.5,
#  19.5,
#  20.5,
#  21.5,
#  22.5,
#  23.5,
#  24.5,
#  25.5]

# %%
y=0
count=0
x=[]
for u,v,a in G.edges(data=True):
    x+=[round((dic[v]-dic[u]),1)]*(a["weight"])
    count=count+a["weight"]
    y=round((dic[v]-dic[u]),1)*a["weight"]+y

# %%
print(x[0:40])
# Out:
# [31.9, 17.6, 6.9, 6.9, 34.1, 34.1, 34.1, 19.0, 19.0, 19.0, 19.0, 19.0, 11.3, 11.3, 11.3, 11.3, 11.3, 11.3, 11.3, 11.3, 13.8, 13.8, 13.8, 13.8, 13.8, 13.8, 13.8, 13.8, 29.8, 29.8, 29.8, 29.8, 29.8, 29.8, 29.8, 29.8, 29.8, 29.8, 29.8, 29.8]

# %%
plt.hist(x, bins, histtype='bar', rwidth=0.5)
# Out:
# (array([ 206619.,  600765.,  163915.,  475282.,  383987.,  207709.,
#         1080637.,  878150.,  587936.,  498089.,  486431.,  692674.,
#          732577., 1507070.,  101173.,  288429.,  161035.,  349492.,
#          119291.,  152153.,  210423.,  561130., 1393774.,  628565.,
#          767651.,  190533.,  656516.,  967704.,  981383.,  717224.,
#          103603.,  339733.,  146030.,  384500.,  123931.,  416182.,
#          154297.,  511083.,   89444.,  446783.,  131708.,   41926.,
#          316873.,  227676.,   18260.,  333021.,   67293.,   45435.,
#          133448.,   22815.,   29924.]),
#  array([-25.5, -24.5, -23.5, -22.5, -21.5, -20.5, -19.5, -18.5, -17.5,
#         -16.5, -15.5, -14.5, -13.5, -12.5, -11.5, -10.5,  -9.5,  -8.5,
#          -7.5,  -6.5,  -5.5,  -4.5,  -3.5,  -2.5,  -1.5,  -0.5,   0.5,
#           1.5,   2.5,   3.5,   4.5,   5.5,   6.5,   7.5,   8.5,   9.5,
#          10.5,  11.5,  12.5,  13.5,  14.5,  15.5,  16.5,  17.5,  18.5,
#          19.5,  20.5,  21.5,  22.5,  23.5,  24.5,  25.5]),
#  <a list of 51 Patch objects>)

# %%
y/count
# Out:
# -5.135138609603003

# %%
plt.hist(x, bins, histtype='bar', rwidth=0.5)
strr="average trend: "+str(round((y/count),1))
plt.text(5, 1.4*1e6, strr)
fig=plt.gcf()
fig.savefig("povertyTT")
plt.show()
